# %%
import pandas as pd
# df = pd.read_csv('Path',sep="分隔符號",names=["欄位"])
users = pd.read_csv('ml-100k/u.user',sep="|",
                   names=["序號","年齡","性別","職業","郵遞區號"])
users
# Out:
#       序號  年齡 性別             職業   郵遞區號
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# 5      6  42  M      executive  98101
# 6      7  57  M  administrator  91344
# 7      8  36  M  administrator  05201
# 8      9  29  M        student  01002
# 9     10  53  M         lawyer  90703
# 10    11  39  F          other  30329
# 11    12  28  F          other  06405
# 12    13  47  M       educator  29206
# 13    14  45  M      scientist  55106
# 14    15  49  F       educator  97301
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 17    18  35  F          other  37212
# 18    19  40  M      librarian  02138
# 19    20  42  F      homemaker  95660
# 20    21  26  M         writer  30068
# 21    22  25  M         writer  40206
# 22    23  30  F         artist  48197
# 23    24  21  F         artist  94533
# ...

# %%
users.head(10)
# users.tail(3)
# Out:
#    序號  年齡 性別             職業   郵遞區號
# 0   1  24  M     technician  85711
# 1   2  53  F          other  94043
# 2   3  23  M         writer  32067
# 3   4  24  M     technician  43537
# 4   5  33  F          other  15213
# 5   6  42  M      executive  98101
# 6   7  57  M  administrator  91344
# 7   8  36  M  administrator  05201
# 8   9  29  M        student  01002
# 9  10  53  M         lawyer  90703

# %%
users[:10]
# users[10:15]
# users[users["年齡"]==39]
# Out:
#    序號  年齡 性別             職業   郵遞區號
# 0   1  24  M     technician  85711
# 1   2  53  F          other  94043
# 2   3  23  M         writer  32067
# 3   4  24  M     technician  43537
# 4   5  33  F          other  15213
# 5   6  42  M      executive  98101
# 6   7  57  M  administrator  91344
# 7   8  36  M  administrator  05201
# 8   9  29  M        student  01002
# 9  10  53  M         lawyer  90703

# %%
users["性別"].head(10)
# Out:
# 0    M
# 1    F
# 2    M
# 3    M
# 4    F
# 5    M
# 6    M
# 7    M
# 8    M
# 9    M
# Name: 性別, dtype: object

# %%
search_col = ["年齡","性別","職業"]
users[search_col].head(10)
# Out:
#    年齡 性別             職業
# 0  24  M     technician
# 1  53  F          other
# 2  23  M         writer
# 3  24  M     technician
# 4  33  F          other
# 5  42  M      executive
# 6  57  M  administrator
# 7  36  M  administrator
# 8  29  M        student
# 9  53  M         lawyer

# %%
#[(條件1) &(條件2)&...]
users[(users.性別=='M') & (users.年齡 < 35)]
# Out:
#       序號  年齡 性別             職業   郵遞區號
# 0      1  24  M     technician  85711
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 8      9  29  M        student  01002
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 20    21  26  M         writer  30068
# 21    22  25  M         writer  40206
# 27    28  32  M         writer  55369
# 29    30   7  M        student  55436
# 30    31  24  M         artist  10003
# 32    33  23  M        student  27510
# 36    37  23  M        student  55105
# 40    41  33  M       engineer  80525
# 41    42  30  M  administrator  17870
# 43    44  26  M     technician  46260
# 44    45  29  M     programmer  50233
# 49    50  21  M         writer  52245
# 50    51  28  M       educator  16509
# 52    53  26  M     programmer  55414
# 53    54  22  M      executive  66315
# 55    56  25  M      librarian  46260
# 56    57  16  M           none  84010
# 57    58  27  M     programmer  52246
# ...

# %%
users[(users.性別=='F') &(users.職業 == 'writer')].head()
# Out:
#       序號  年齡 性別      職業   郵遞區號
# 121  122  32  F  writer  22206
# 235  236  44  F  writer  53214
# 263  264  36  F  writer  90064
# 388  389  44  F  writer  83702
# 389  390  42  F  writer  85016

# %%
users[(users.性別=='M') |(users.年齡 > 60)].head(5)
# Out:
#    序號  年齡 性別             職業   郵遞區號
# 0   1  24  M     technician  85711
# 2   3  23  M         writer  32067
# 3   4  24  M     technician  43537
# 5   6  42  M      executive  98101
# 6   7  57  M  administrator  91344

# %%
users.dtypes
# Out:
# 序號       int64
# 年齡       int64
# 性別      object
# 職業      object
# 郵遞區號    object
# dtype: object

# %%
users.describe()
# Out:
#                序號          年齡
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
# users.set_index("序號").head()
users.head(5)
users.set_index('序號',inplace= True)
# Out:
#    序號  年齡 性別          職業   郵遞區號
# 0   1  24  M  technician  85711
# 1   2  53  F       other  94043
# 2   3  23  M      writer  32067
# 3   4  24  M  technician  43537
# 4   5  33  F       other  15213

# %%
users.head(5)
# Out:
#     年齡 性別          職業   郵遞區號
# 序號
# 1   24  M  technician  85711
# 2   53  F       other  94043
# 3   23  M      writer  32067
# 4   24  M  technician  43537
# 5   33  F       other  15213

# %%
users.ix[[1,20,30]] #選取對應index_label的資料
# Out:
#     年齡 性別          職業   郵遞區號
# 序號
# 1   24  M  technician  85711
# 20  42  F   homemaker  95660
# 30   7  M     student  55436
